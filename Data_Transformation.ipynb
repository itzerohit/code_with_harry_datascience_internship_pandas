# %%
import pandas as pd

df = pd.read_csv("rohit.csv")

# %%
df
# Out:
#                  Actor                      Film  Year  BoxOffice(INR Crore)  \
# 0       Shah Rukh Khan                   Pathaan  2023                  1050
# 1          Salman Khan           Tiger Zinda Hai  2017                   565
# 2            Amir Khan                    Dangal  2016                  2024
# 3        Ranbir Kapoor                Brahmastra  2022                   431
# 4        Ranveer Singh                 Padmaavat  2018                   585
# 5   Ayushmann Khurrana                 Andhadhun  2018                   111
# 6         Rajkumar Rao                     Stree  2018                   180
# 7       Hrithik Roshan                       War  2019                   475
# 8         Akshay Kumar                Good Newwz  2019                   318
# 9        Kartik Aaryan           Bhool Bhulaiyaa  2022                   266
# 10        Varun Dhawan    Badrinath Ki Dulhanyia  2017                   201
# ...

# %%
df.sort_values("Actor")
# Out:
#                  Actor                      Film  Year  BoxOffice(INR Crore)  \
# 8         Akshay Kumar                Good Newwz  2019                   318
# 2            Amir Khan                    Dangal  2016                  2024
# 5   Ayushmann Khurrana                 Andhadhun  2018                   111
# 7       Hrithik Roshan                       War  2019                   475
# 9        Kartik Aaryan           Bhool Bhulaiyaa  2022                   266
# 6         Rajkumar Rao                     Stree  2018                   180
# 3        Ranbir Kapoor                Brahmastra  2022                   431
# 4        Ranveer Singh                 Padmaavat  2018                   585
# 1          Salman Khan           Tiger Zinda Hai  2017                   565
# 0       Shah Rukh Khan                   Pathaan  2023                  1050
# 10        Varun Dhawan    Badrinath Ki Dulhanyia  2017                   201
# ...

# %%
df.sort_values("Film")
# Out:
#                  Actor                      Film  Year  BoxOffice(INR Crore)  \
# 5   Ayushmann Khurrana                 Andhadhun  2018                   111
# 10        Varun Dhawan    Badrinath Ki Dulhanyia  2017                   201
# 9        Kartik Aaryan           Bhool Bhulaiyaa  2022                   266
# 3        Ranbir Kapoor                Brahmastra  2022                   431
# 2            Amir Khan                    Dangal  2016                  2024
# 8         Akshay Kumar                Good Newwz  2019                   318
# 4        Ranveer Singh                 Padmaavat  2018                   585
# 0       Shah Rukh Khan                   Pathaan  2023                  1050
# 6         Rajkumar Rao                     Stree  2018                   180
# 1          Salman Khan           Tiger Zinda Hai  2017                   565
# 11      Vicky Kaushal   Uri: The surgical strike  2019                   342
# ...

# %%
df.sort_values("Year", ascending = False)
# Out:
#                  Actor                      Film  Year  BoxOffice(INR Crore)  \
# 0       Shah Rukh Khan                   Pathaan  2023                  1050
# 3        Ranbir Kapoor                Brahmastra  2022                   431
# 9        Kartik Aaryan           Bhool Bhulaiyaa  2022                   266
# 7       Hrithik Roshan                       War  2019                   475
# 8         Akshay Kumar                Good Newwz  2019                   318
# 11      Vicky Kaushal   Uri: The surgical strike  2019                   342
# 6         Rajkumar Rao                     Stree  2018                   180
# 5   Ayushmann Khurrana                 Andhadhun  2018                   111
# 4        Ranveer Singh                 Padmaavat  2018                   585
# 1          Salman Khan           Tiger Zinda Hai  2017                   565
# 10        Varun Dhawan    Badrinath Ki Dulhanyia  2017                   201
# ...

# %%
df.sort_values("Year", ascending = True)
# Out:
#                  Actor                      Film  Year  BoxOffice(INR Crore)  \
# 2            Amir Khan                    Dangal  2016                  2024
# 1          Salman Khan           Tiger Zinda Hai  2017                   565
# 10        Varun Dhawan    Badrinath Ki Dulhanyia  2017                   201
# 5   Ayushmann Khurrana                 Andhadhun  2018                   111
# 6         Rajkumar Rao                     Stree  2018                   180
# 4        Ranveer Singh                 Padmaavat  2018                   585
# 8         Akshay Kumar                Good Newwz  2019                   318
# 7       Hrithik Roshan                       War  2019                   475
# 11      Vicky Kaushal   Uri: The surgical strike  2019                   342
# 3        Ranbir Kapoor                Brahmastra  2022                   431
# 9        Kartik Aaryan           Bhool Bhulaiyaa  2022                   266
# ...

# %%
df2 = df.sort_values(["Year","IMDb"]).copy()

# %%
df2.reset_index(drop=True, inplace=True)  # Reset the index and drop the old index

# %%
df2
# Out:
#                  Actor                      Film  Year  BoxOffice(INR Crore)  \
# 0            Amir Khan                    Dangal  2016                  2024
# 1          Salman Khan           Tiger Zinda Hai  2017                   565
# 2         Varun Dhawan    Badrinath Ki Dulhanyia  2017                   201
# 3        Ranveer Singh                 Padmaavat  2018                   585
# 4         Rajkumar Rao                     Stree  2018                   180
# 5   Ayushmann Khurrana                 Andhadhun  2018                   111
# 6       Hrithik Roshan                       War  2019                   475
# 7         Akshay Kumar                Good Newwz  2019                   318
# 8       Vicky Kaushal   Uri: The surgical strike  2019                   342
# 9        Ranbir Kapoor                Brahmastra  2022                   431
# 10       Kartik Aaryan           Bhool Bhulaiyaa  2022                   266
# ...

# %%
df2.sort_index()
# Out:
#                  Actor                      Film  Year  BoxOffice(INR Crore)  \
# 0            Amir Khan                    Dangal  2016                  2024
# 1          Salman Khan           Tiger Zinda Hai  2017                   565
# 2         Varun Dhawan    Badrinath Ki Dulhanyia  2017                   201
# 3        Ranveer Singh                 Padmaavat  2018                   585
# 4         Rajkumar Rao                     Stree  2018                   180
# 5   Ayushmann Khurrana                 Andhadhun  2018                   111
# 6       Hrithik Roshan                       War  2019                   475
# 7         Akshay Kumar                Good Newwz  2019                   318
# 8       Vicky Kaushal   Uri: The surgical strike  2019                   342
# 9        Ranbir Kapoor                Brahmastra  2022                   431
# 10       Kartik Aaryan           Bhool Bhulaiyaa  2022                   266
# ...

# %%
df.sort_index()
# Out:
#                  Actor                      Film  Year  BoxOffice(INR Crore)  \
# 0       Shah Rukh Khan                   Pathaan  2023                  1050
# 1          Salman Khan           Tiger Zinda Hai  2017                   565
# 2            Amir Khan                    Dangal  2016                  2024
# 3        Ranbir Kapoor                Brahmastra  2022                   431
# 4        Ranveer Singh                 Padmaavat  2018                   585
# 5   Ayushmann Khurrana                 Andhadhun  2018                   111
# 6         Rajkumar Rao                     Stree  2018                   180
# 7       Hrithik Roshan                       War  2019                   475
# 8         Akshay Kumar                Good Newwz  2019                   318
# 9        Kartik Aaryan           Bhool Bhulaiyaa  2022                   266
# 10        Varun Dhawan    Badrinath Ki Dulhanyia  2017                   201
# ...

# %% [markdown]
# Rank

# %%
df2["Rank"] = df2["IMDb"].rank(method="dense", ascending=False)

# %%
df2["Rank"]
# Out:
# 0      1.0
# 1      9.0
# 2      8.0
# 3      6.0
# 4      4.0
# 5      2.0
# 6      7.0
# 7      6.0
# 8      3.0
# 9     11.0
# 10    10.0
# 11     5.0
# Name: Rank, dtype: float64

# %%
df2
# Out:
#                  Actor                      Film  Year  BoxOffice(INR Crore)  \
# 0            Amir Khan                    Dangal  2016                  2024
# 1          Salman Khan           Tiger Zinda Hai  2017                   565
# 2         Varun Dhawan    Badrinath Ki Dulhanyia  2017                   201
# 3        Ranveer Singh                 Padmaavat  2018                   585
# 4         Rajkumar Rao                     Stree  2018                   180
# 5   Ayushmann Khurrana                 Andhadhun  2018                   111
# 6       Hrithik Roshan                       War  2019                   475
# 7         Akshay Kumar                Good Newwz  2019                   318
# 8       Vicky Kaushal   Uri: The surgical strike  2019                   342
# 9        Ranbir Kapoor                Brahmastra  2022                   431
# 10       Kartik Aaryan           Bhool Bhulaiyaa  2022                   266
# ...

# %% [markdown]
# Renaming Columns and Index

# %%
df2.rename(columns={"Actor":"ACTOR"},inplace=True)

# %%
df2
# Out:
#                  ACTOR                      Film  Year  BoxOffice(INR Crore)  \
# 0            Amir Khan                    Dangal  2016                  2024
# 1          Salman Khan           Tiger Zinda Hai  2017                   565
# 2         Varun Dhawan    Badrinath Ki Dulhanyia  2017                   201
# 3        Ranveer Singh                 Padmaavat  2018                   585
# 4         Rajkumar Rao                     Stree  2018                   180
# 5   Ayushmann Khurrana                 Andhadhun  2018                   111
# 6       Hrithik Roshan                       War  2019                   475
# 7         Akshay Kumar                Good Newwz  2019                   318
# 8       Vicky Kaushal   Uri: The surgical strike  2019                   342
# 9        Ranbir Kapoor                Brahmastra  2022                   431
# 10       Kartik Aaryan           Bhool Bhulaiyaa  2022                   266
# ...

# %% [markdown]
# Changing Column Order

# %%
df
# Out:
#                  Actor                      Film  Year  BoxOffice(INR Crore)  \
# 0       Shah Rukh Khan                   Pathaan  2023                  1050
# 1          Salman Khan           Tiger Zinda Hai  2017                   565
# 2            Amir Khan                    Dangal  2016                  2024
# 3        Ranbir Kapoor                Brahmastra  2022                   431
# 4        Ranveer Singh                 Padmaavat  2018                   585
# 5   Ayushmann Khurrana                 Andhadhun  2018                   111
# 6         Rajkumar Rao                     Stree  2018                   180
# 7       Hrithik Roshan                       War  2019                   475
# 8         Akshay Kumar                Good Newwz  2019                   318
# 9        Kartik Aaryan           Bhool Bhulaiyaa  2022                   266
# 10        Varun Dhawan    Badrinath Ki Dulhanyia  2017                   201
# ...

# %%
df = df[["Film","Year","Actor","IMDb","BoxOffice(INR Crore)"]]

# %%
df
# Out:
#                         Film  Year               Actor  IMDb  \
# 0                    Pathaan  2023      Shah Rukh Khan   7.2
# 1            Tiger Zinda Hai  2017         Salman Khan   6.0
# 2                     Dangal  2016           Amir Khan   8.4
# 3                 Brahmastra  2022       Ranbir Kapoor   5.6
# 4                  Padmaavat  2018       Ranveer Singh   7.0
# 5                  Andhadhun  2018  Ayushmann Khurrana   8.3
# 6                      Stree  2018        Rajkumar Rao   7.5
# 7                        War  2019      Hrithik Roshan   6.5
# 8                 Good Newwz  2019        Akshay Kumar   7.0
# 9            Bhool Bhulaiyaa  2022       Kartik Aaryan   5.9
# 10    Badrinath Ki Dulhanyia  2017        Varun Dhawan   6.1
# 11  Uri: The surgical strike  2019      Vicky Kaushal    8.2
#
#     BoxOffice(INR Crore)
# 0                   1050
# 1                    565
# 2                   2024
# 3                    431
# 4                    585
# ...

# %%
# You can also move one column to the front

# %%
cols = ["Actor"] + [col for col in df.columns if col != "Actor"]
df = df[cols]

# %%
df
# Out:
#                  Actor                      Film  Year  IMDb  \
# 0       Shah Rukh Khan                   Pathaan  2023   7.2
# 1          Salman Khan           Tiger Zinda Hai  2017   6.0
# 2            Amir Khan                    Dangal  2016   8.4
# 3        Ranbir Kapoor                Brahmastra  2022   5.6
# 4        Ranveer Singh                 Padmaavat  2018   7.0
# 5   Ayushmann Khurrana                 Andhadhun  2018   8.3
# 6         Rajkumar Rao                     Stree  2018   7.5
# 7       Hrithik Roshan                       War  2019   6.5
# 8         Akshay Kumar                Good Newwz  2019   7.0
# 9        Kartik Aaryan           Bhool Bhulaiyaa  2022   5.9
# 10        Varun Dhawan    Badrinath Ki Dulhanyia  2017   6.1
# 11      Vicky Kaushal   Uri: The surgical strike  2019   8.2
#
#     BoxOffice(INR Crore)
# 0                   1050
# 1                    565
# 2                   2024
# 3                    431
# 4                    585
# ...

# %% [markdown]
# # Summary
# . Sort, rank, and rename to prepare your data
# . Reordering and reshaping are key for EDA and visualization
